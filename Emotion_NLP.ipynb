# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_csv(r"C:\Users\HP\Documents\Emotion_classify_Data.csv")
# Out:
#                                                 Comment Emotion
# 0     i seriously hate one subject to death but now ...    fear
# 1                    im so full of life i feel appalled   anger
# 2     i sit here to write i start to dig out my feel...    fear
# 3     ive been really angry with r and i feel like a...     joy
# 4     i feel suspicious if there is no one outside l...    fear
# ...                                                 ...     ...
# 5932                 i begun to feel distressed for you    fear
# 5933  i left feeling annoyed and angry thinking that...   anger
# 5934  i were to ever get married i d have everything...     joy
# 5935  i feel reluctant in applying there because i w...    fear
# 5936  i just wanted to apologize to you because i fe...   anger
#
# [5937 rows x 2 columns]

# %%
df=pd.read_csv(r"C:\Users\HP\Documents\Emotion_classify_Data.csv")

# %%
df.shape
# Out:
# (5937, 2)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                 Comment Emotion
# 0     i seriously hate one subject to death but now ...    fear
# 1                    im so full of life i feel appalled   anger
# 2     i sit here to write i start to dig out my feel...    fear
# 3     ive been really angry with r and i feel like a...     joy
# 4     i feel suspicious if there is no one outside l...    fear
# ...                                                 ...     ...
# 5932                 i begun to feel distressed for you    fear
# 5933  i left feeling annoyed and angry thinking that...   anger
# 5934  i were to ever get married i d have everything...     joy
# 5935  i feel reluctant in applying there because i w...    fear
# 5936  i just wanted to apologize to you because i fe...   anger
#
# [5937 rows x 2 columns]>

# %%
df['Comment']
# Out:
# 0       i seriously hate one subject to death but now ...
# 1                      im so full of life i feel appalled
# 2       i sit here to write i start to dig out my feel...
# 3       ive been really angry with r and i feel like a...
# 4       i feel suspicious if there is no one outside l...
#                               ...
# 5932                   i begun to feel distressed for you
# 5933    i left feeling annoyed and angry thinking that...
# 5934    i were to ever get married i d have everything...
# 5935    i feel reluctant in applying there because i w...
# 5936    i just wanted to apologize to you because i fe...
# Name: Comment, Length: 5937, dtype: object

# %%
df['Comment'].values[0]
# Out:
# 'i seriously hate one subject to death but now i feel reluctant to drop it'

# %%
df['Comment'].values[5936]
# Out:
# 'i just wanted to apologize to you because i feel like a heartless bitch'

# %%
emotion_counts = df['Emotion'].value_counts()

# %%
print(emotion_counts)
# Out:
# Emotion
# anger    2000
# joy      2000
# fear     1937
# Name: count, dtype: int64

# %%
# Filter for only 'joy' comments
df_joy = df[df['Emotion'] == 'joy']

# %%
print(df_joy)
# Out:
#                                                 Comment Emotion
# 3     ive been really angry with r and i feel like a...     joy
# 9     i feel like i ve regained another vital part o...     joy
# 10    i feel a bit like franz liebkind in the produc...     joy
# 11    i was feeling at the start didnt want to move ...     joy
# 13    i do not always find myself feeling thankful b...     joy
# ...                                                 ...     ...
# 5917         i feel re invigorated and full of ambition     joy
# 5921  i feel instantly glamorous just pulling it out...     joy
# 5922  i feel wonderful and i m very very grateful fo...     joy
# 5931  i have lost touch with the things that i feel ...     joy
# 5934  i were to ever get married i d have everything...     joy
#
# [2000 rows x 2 columns]

# %%
# Filter for only 'anger' comments
df_anger = df[df['Emotion'] == 'anger']

# %%
print(df_anger)
# Out:
#                                                 Comment Emotion
# 1                    im so full of life i feel appalled   anger
# 5     i feel jealous becasue i wanted that kind of l...   anger
# 6     when a friend of mine keeps telling me morbid ...   anger
# 7     i finally fell asleep feeling angry useless an...   anger
# 8          i feel a bit annoyed and antsy in a good way   anger
# ...                                                 ...     ...
# 5925                 i am feeling bitchy cross whatever   anger
# 5928  i feel angry because i have led myself to lead...   anger
# 5929  i mean weve been friends for a long time and t...   anger
# 5933  i left feeling annoyed and angry thinking that...   anger
# 5936  i just wanted to apologize to you because i fe...   anger
#
# [2000 rows x 2 columns]

# %%
# Filter for only 'fear' comments
df_fear = df[df['Emotion'] == 'fear']

# %%
print(df_fear)
# Out:
#                                                 Comment Emotion
# 0     i seriously hate one subject to death but now ...    fear
# 2     i sit here to write i start to dig out my feel...    fear
# 4     i feel suspicious if there is no one outside l...    fear
# 12                                i was bitten by a dog    fear
# 19    i feel like i have to redeem myself even thoug...    fear
# ...                                                 ...     ...
# 5926  i must say that there were all familiar faces ...    fear
# 5927  i have never done anything to make her cry or ...    fear
# 5930  i think we often feel this way about planting ...    fear
# 5932                 i begun to feel distressed for you    fear
# 5935  i feel reluctant in applying there because i w...    fear
#
# [1937 rows x 2 columns]

# %%
# Plot the data using Matplotlib
plt.figure(figsize=(8, 5))
plt.bar(emotion_counts.index, emotion_counts.values, color='blue')
plt.xlabel("Emotion")
plt.ylabel("Count")
plt.title("Emotion Distribution in Comments")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Basic NLTK

# %%
import nltk

# %%
pip install --upgrade nltk
# Out:
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.5 MB 682.7 kB/s eta 0:00:03
#     --------------------------------------- 0.0/1.5 MB 682.7 kB/s eta 0:00:03
#    - -------------------------------------- 0.0/1.5 MB 281.8 kB/s eta 0:00:06
#    - -------------------------------------- 0.0/1.5 MB 281.8 kB/s eta 0:00:06
#    - -------------------------------------- 0.0/1.5 MB 281.8 kB/s eta 0:00:06
#    - -------------------------------------- 0.0/1.5 MB 281.8 kB/s eta 0:00:06
#    - -------------------------------------- 0.0/1.5 MB 281.8 kB/s eta 0:00:06
#    -- ------------------------------------- 0.1/1.5 MB 262.6 kB/s eta 0:00:06
#    -- ------------------------------------- 0.1/1.5 MB 262.6 kB/s eta 0:00:06
# ...

# %%
nltk.download('vader_lexicon')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
example = df['Comment'][3]

# %%
print(example)
# Out:
# ive been really angry with r and i feel like an idiot for trusting him in the first place

# %%
nltk.word_tokenize(example)
# Out:
# ['ive',
#  'been',
#  'really',
#  'angry',
#  'with',
#  'r',
#  'and',
#  'i',
#  'feel',
#  'like',
#  'an',
#  'idiot',
#  'for',
#  'trusting',
#  'him',
#  'in',
#  'the',
#  'first',
#  'place']

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['ive', 'been', 'really', 'angry', 'with', 'r', 'and', 'i', 'feel', 'like']

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sia.polarity_scores('There are moments when I wish I could roll back the clock and take all the sadness away, but I have the feeling that if I did, the joy would be gone as wel')
# Out:
# {'neg': 0.053, 'neu': 0.707, 'pos': 0.239, 'compound': 0.7814}

# %%
sia.polarity_scores('This is the worst thing ever.')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
example
# Out:
# 'ive been really angry with r and i feel like an idiot for trusting him in the first place'

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.275, 'neu': 0.518, 'pos': 0.207, 'compound': -0.4005}

# %%
# Run polarity score on the entire dataset
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row["Comment"]
    myid = i  # Use index as ID if 'Id' column is not available
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/5937 [00:00<?, ?it/s]

# %%
res
# Out:
# {0: {'neg': 0.585, 'neu': 0.415, 'pos': 0.0, 'compound': -0.8519},
#  1: {'neg': 0.333, 'neu': 0.667, 'pos': 0.0, 'compound': -0.4588},
#  2: {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.3818},
#  3: {'neg': 0.275, 'neu': 0.518, 'pos': 0.207, 'compound': -0.4005},
#  4: {'neg': 0.237, 'neu': 0.556, 'pos': 0.207, 'compound': -0.1531},
#  5: {'neg': 0.127, 'neu': 0.591, 'pos': 0.283, 'compound': 0.5729},
#  6: {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.4939},
#  7: {'neg': 0.479, 'neu': 0.429, 'pos': 0.092, 'compound': -0.743},
#  8: {'neg': 0.226, 'neu': 0.522, 'pos': 0.252, 'compound': 0.0772},
#  9: {'neg': 0.0, 'neu': 0.701, 'pos': 0.299, 'compound': 0.5719},
#  10: {'neg': 0.0, 'neu': 0.742, 'pos': 0.258, 'compound': 0.7096},
#  11: {'neg': 0.031, 'neu': 0.636, 'pos': 0.333, 'compound': 0.8976},
#  12: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  13: {'neg': 0.038, 'neu': 0.63, 'pos': 0.332, 'compound': 0.91},
# ...

# %%
# Convert results to DataFrame
sentiment_df = pd.DataFrame.from_dict(res, orient='index')

# %%
df = df.reset_index(drop=True)  # Ensure index matches

# %%
# Merge with the original dataset
df = pd.concat([df, sentiment_df], axis=1)

# %%
df
# Out:
#                                                 Comment Emotion    neg    neu  \
# 0     i seriously hate one subject to death but now ...    fear  0.585  0.415
# 1                    im so full of life i feel appalled   anger  0.333  0.667
# 2     i sit here to write i start to dig out my feel...    fear  0.000  0.902
# 3     ive been really angry with r and i feel like a...     joy  0.275  0.518
# 4     i feel suspicious if there is no one outside l...    fear  0.237  0.556
# ...                                                 ...     ...    ...    ...
# 5932                 i begun to feel distressed for you    fear  0.359  0.641
# 5933  i left feeling annoyed and angry thinking that...   anger  0.423  0.409
# 5934  i were to ever get married i d have everything...     joy  0.000  0.748
# 5935  i feel reluctant in applying there because i w...    fear  0.099  0.837
# 5936  i just wanted to apologize to you because i fe...   anger  0.391  0.391
#
# ...

# %%
df.head(5)
# Out:
#                                              Comment Emotion    neg    neu  \
# 0  i seriously hate one subject to death but now ...    fear  0.585  0.415
# 1                 im so full of life i feel appalled   anger  0.333  0.667
# 2  i sit here to write i start to dig out my feel...    fear  0.000  0.902
# 3  ive been really angry with r and i feel like a...     joy  0.275  0.518
# 4  i feel suspicious if there is no one outside l...    fear  0.237  0.556
#
#      pos  compound    neg    neu    pos  compound
# 0  0.000   -0.8519  0.585  0.415  0.000   -0.8519
# 1  0.000   -0.4588  0.333  0.667  0.000   -0.4588
# 2  0.098    0.3818  0.000  0.902  0.098    0.3818
# 3  0.207   -0.4005  0.275  0.518  0.207   -0.4005
# 4  0.207   -0.1531  0.237  0.556  0.207   -0.1531

# %%
import seaborn as sns

# %%
# Plot the emotion distribution
plt.figure(figsize=(8, 5))
sns.countplot(x=df["Emotion"], palette="viridis", order=df["Emotion"].value_counts().index)
plt.xlabel("Emotion")
plt.ylabel("Count")
plt.title("Emotion Distribution in Comments")
plt.xticks(rotation=45)
plt.show()

# %%
#Drop duplicate columns if they exist
sentiment_df = sentiment_df.loc[:, ~sentiment_df.columns.duplicated()]

# %%
 # Visualize sentiment scores
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

sns.barplot(data=sentiment_df, x=sentiment_df.index, y='pos', ax=axs[0], color='green')
sns.barplot(data=sentiment_df, x=sentiment_df.index, y='neu', ax=axs[1], color='blue')
sns.barplot(data=sentiment_df, x=sentiment_df.index, y='neg', ax=axs[2], color='red')

axs[0].set_title('Positive Sentiment')
axs[1].set_title('Neutral Sentiment')
axs[2].set_title('Negative Sentiment')

for ax in axs:
    ax.set_xticklabels([])  # Hide x-axis labels to avoid clutter

plt.tight_layout()
plt.show()
